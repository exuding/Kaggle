# %%
import os
import re
import gc
import pickle  
import random
import keras

import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_hub as hub
import keras.backend as K

from keras.models import Model
from keras.layers import Dense, Input, Dropout, Lambda
from keras.optimizers import Adam
from keras.callbacks import Callback
from scipy.stats import spearmanr, rankdata
from os.path import join as path_join
from numpy.random import seed
from urllib.parse import urlparse
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import KFold
from sklearn.linear_model import MultiTaskElasticNet
import lightgbm as lgb
from sklearn import metrics

seed(42)
tf.random.set_seed(42)
random.seed(42)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# * Thanks to https://www.kaggle.com/abazdyrev/use-features-oof with the preprocessing part

# %%
def read_data():
    data_dir = '../input/google-quest-challenge/'
    print('Reading train set')
    train = pd.read_csv(path_join(data_dir, 'train.csv'))
    print('Reading test set')
    test = pd.read_csv(path_join(data_dir, 'test.csv'))
    print('Our training data have {} rows and {} columns'.format(train.shape[0], train.shape[1]))
    print('Our testing data have {} rows and {} columns'.format(test.shape[0], test.shape[1]))
    return train, test

# %%
# 30 target variables where the range is [0, 1]
targets = ['question_asker_intent_understanding', 'question_body_critical', 'question_conversational', 
           'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer', 
           'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
           'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice', 
           'question_type_compare', 'question_type_consequence', 'question_type_definition', 
           'question_type_entity', 'question_type_instructions', 'question_type_procedure', 
           'question_type_reason_explanation', 'question_type_spelling', 'question_well_written', 
           'answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance', 
           'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
           'answer_type_reason_explanation', 'answer_well_written']

# text features, using embedding trained model to preprocess them
input_columns = ['question_title', 'question_body', 'answer']

# %%
# get categorical features and ohe
def get_cat_features(train, test):
    find = re.compile(r"^[^.]*")

    train['netloc'] = train['url'].apply(lambda x: re.findall(find, urlparse(x).netloc)[0])
    test['netloc'] = test['url'].apply(lambda x: re.findall(find, urlparse(x).netloc)[0])

    features = ['netloc', 'category']
    merged = pd.concat([train[features], test[features]])
    ohe = OneHotEncoder()
    ohe.fit(merged)
    
    # one hot encode netloc and category
    features_train = ohe.transform(train[features]).toarray()
    features_test = ohe.transform(test[features]).toarray()
    print('Our categorical features have {} rows and {} columns'.format(features_train.shape[0], features_train.shape[1]))
    return features_train, features_test

# %%
def get_embedding_features(train, test, input_columns):
    
    # load universal sentence encoder model to get sentence ambeddings
    module_url = "../input/universalsentenceencoderlarge4/"
    embed = hub.load(module_url)
    
    # create empty dictionaries to store final results
    embedding_train = {}
    embedding_test = {}

    # iterate over text columns to get senteces embeddings with the previous loaded model
    for text in input_columns:
    
        print(text)
        train_text = train[text].str.replace('?', '.').str.replace('!', '.').tolist()
        test_text = test[text].str.replace('?', '.').str.replace('!', '.').tolist()
    
        # create empy list to save each batch
        curr_train_emb = []
        curr_test_emb = []
    
        # define a batch to transform senteces to their correspinding embedding (1 X 512 for each sentece)
        batch_size = 4
        ind = 0
        while ind * batch_size < len(train_text):
            curr_train_emb.append(embed(train_text[ind * batch_size: (ind + 1) * batch_size])['outputs'].numpy())
            ind += 1
        
        ind = 0
        while ind * batch_size < len(test_text):
            curr_test_emb.append(embed(test_text[ind * batch_size: (ind + 1) * batch_size])['outputs'].numpy())
            ind += 1

        # stack arrays to get a 2D array (dataframe) corresponding with all the sentences and dim 512 for columns (sentence encoder output)
        embedding_train[text + '_embedding'] = np.vstack(curr_train_emb)
        embedding_test[text + '_embedding'] = np.vstack(curr_test_emb)
    
    del embed
    K.clear_session()
    gc.collect()
    
    return embedding_train, embedding_test

# %% [markdown]
# * We have our categorical array of dimension 6079 x 64
# * We have our embedding dict were each key have a dimension of 6079 x 512, we have 3 keys that corresponds to the embedding of the sentece of question title, question body and answer.

# %%
def get_dist_features(embedding_train, embedding_test, features_train, features_test):
    
    # define a square dist lambda function were (x1 - y1) ^ 2 + (x2 - y2) ^ 2 + (x3 - y3) ^ 2 + ... + (xn - yn) ^ 2
    # with this we get one vector of dimension 6079
    l2_dist = lambda x, y: np.power(x - y, 2).sum(axis = 1)
    
    # define a cosine dist lambda function were (x1 * y1) ^ 2 + (x2 * y2) + (x3 * y3) + ... + (xn * yn)
    cos_dist = lambda x, y: (x * y).sum(axis = 1)
    
    # transpose it because we have 6 vector of dimension 6079, need 6079 x 6
    dist_features_train = np.array([
        l2_dist(embedding_train['question_title_embedding'], embedding_train['answer_embedding']),
        l2_dist(embedding_train['question_body_embedding'], embedding_train['answer_embedding']),
        l2_dist(embedding_train['question_body_embedding'], embedding_train['question_title_embedding']),
        cos_dist(embedding_train['question_title_embedding'], embedding_train['answer_embedding']),
        cos_dist(embedding_train['question_body_embedding'], embedding_train['answer_embedding']),
        cos_dist(embedding_train['question_body_embedding'], embedding_train['question_title_embedding'])]).T
    
    # transpose it because we have 6 vector of dimension 6079, need 6079 x 6
    dist_features_test = np.array([
        l2_dist(embedding_test['question_title_embedding'], embedding_test['answer_embedding']),
        l2_dist(embedding_test['question_body_embedding'], embedding_test['answer_embedding']),
        l2_dist(embedding_test['question_body_embedding'], embedding_test['question_title_embedding']),
        cos_dist(embedding_test['question_title_embedding'], embedding_test['answer_embedding']),
        cos_dist(embedding_test['question_body_embedding'], embedding_test['answer_embedding']),
        cos_dist(embedding_test['question_body_embedding'], embedding_test['question_title_embedding'])]).T
    
    # get the values of each key, therefore we have 3 arrays of dim 6079 x 512 (hstack to get 6079 x 1536)
    x_train = np.hstack([values for key, values in embedding_train.items()] + [features_train, dist_features_train])
    x_test = np.hstack([values for key, values in embedding_test.items()] + [features_test, dist_features_test])
    print('Our preprocess training set have {} rows and {} columns'.format(x_train.shape[0], x_train.shape[1]))
    print('Our preprocess testing set have {} rows and {} columns'.format(x_test.shape[0], x_test.shape[1]))
    
    return pd.DataFrame(x_train), pd.DataFrame(x_test)

# %%
def run_lgb(x_train, x_test, train, target):
    
    # 5 random KFold
    kf = KFold(n_splits = 10, random_state = 42)
    
    # get empty vectors (0) to store out of fold predictions and test predictions
    oof_pred = np.zeros(len(x_train))
    y_pred = np.zeros(len(x_test))
    
    # for each fold train a model and then get the mean to predict the test
    for fold, (tr_ind, val_ind) in enumerate(kf.split(x_train)):
        print('Fold {}'.format(fold + 1))
        x_trn, x_val = x_train.iloc[tr_ind], x_train.iloc[val_ind]
        y_trn, y_val = train[target].iloc[tr_ind], train[target].iloc[val_ind]
        train_set = lgb.Dataset(x_trn, y_trn)
        val_set = lgb.Dataset(x_val, y_val)

        params = {
            'learning_rate': 0.1,
            'metric': 'rmse',
            'objective': 'regression',
            'feature_fraction': 0.85,
            'subsample': 0.85,
            'n_jobs': -1,
            'seed': 42,
            'max_depth': -1
        }
        
        # train the model with early stoping
        model = lgb.train(params, train_set, num_boost_round = 1000000, early_stopping_rounds = 10, 
                          valid_sets=[train_set, val_set], verbose_eval = 10)
        oof_pred[val_ind] = model.predict(x_val)
        y_pred += model.predict(x_test) / kf.n_splits
    loss_score = np.sqrt(metrics.mean_squared_error(train[target], oof_pred))
    print('Our oof rmse score is: ', loss_score)
    return y_pred

def predict(x_train, x_test, train, targets):
    predictions = []
    for num, target in enumerate(targets):
        print('Train model {}'.format(num + 1))
        print('Predicting target {}'.format(target))
        predictions.append(np.clip(run_lgb(x_train, x_test, train, target), a_min = 0, a_max = 1))
    data_dir = '../input/google-quest-challenge/'
    submission = pd.read_csv(path_join(data_dir, 'sample_submission.csv'))
    submission[targets] = np.array(predictions).T
    submission.to_csv('submission.csv', index = False)

# %%
# run all
# read training and test data
train, test = read_data()
# get one hot encoded categorical data
features_train, features_test = get_cat_features(train, test)
# get embedding features
embedding_train, embedding_test = get_embedding_features(train, test, input_columns)
# get dist features from the embedding features and concatenate with embedding and categorical features
x_train, x_test = get_dist_features(embedding_train, embedding_test, features_train, features_test)
# trian and predict
predict(x_train, x_test, train, targets)
# Out:
# Reading train set
# Reading test set
# Our training data have 6079 rows and 41 columns
# Our testing data have 476 rows and 11 columns
# Our categorical features have 6079 rows and 64 columns
# question_title
# question_body
# answer
# Our preprocess training set have 6079 rows and 1606 columns
# Our preprocess testing set have 476 rows and 1606 columns
# Train model 1
# Predicting target question_asker_intent_understanding
# Fold 1
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.112448	valid_1's rmse: 0.131624
# [20]	training's rmse: 0.0997769	valid_1's rmse: 0.131103
# [30]	training's rmse: 0.0897611	valid_1's rmse: 0.131195
# Early stopping, best iteration is:
# [22]	training's rmse: 0.0975954	valid_1's rmse: 0.130851
# Fold 2
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.112649	valid_1's rmse: 0.13331
# [20]	training's rmse: 0.0998154	valid_1's rmse: 0.132218
# [30]	training's rmse: 0.0896772	valid_1's rmse: 0.132467
# Early stopping, best iteration is:
# [25]	training's rmse: 0.0945872	valid_1's rmse: 0.131867
# Fold 3
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.113474	valid_1's rmse: 0.123207
# [20]	training's rmse: 0.100404	valid_1's rmse: 0.122138
# [30]	training's rmse: 0.0906183	valid_1's rmse: 0.121494
# [40]	training's rmse: 0.0823221	valid_1's rmse: 0.122223
# Early stopping, best iteration is:
# [31]	training's rmse: 0.0897293	valid_1's rmse: 0.121423
# Fold 4
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.112644	valid_1's rmse: 0.130798
# [20]	training's rmse: 0.09998	valid_1's rmse: 0.130186
# Early stopping, best iteration is:
# [13]	training's rmse: 0.108486	valid_1's rmse: 0.12989
# Fold 5
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.114083	valid_1's rmse: 0.116861
# [20]	training's rmse: 0.101304	valid_1's rmse: 0.115847
# [30]	training's rmse: 0.0913059	valid_1's rmse: 0.115316
# [40]	training's rmse: 0.0828502	valid_1's rmse: 0.115165
# [50]	training's rmse: 0.0757053	valid_1's rmse: 0.115104
# Early stopping, best iteration is:
# [43]	training's rmse: 0.0806546	valid_1's rmse: 0.114889
# Fold 6
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.113683	valid_1's rmse: 0.124006
# [20]	training's rmse: 0.10094	valid_1's rmse: 0.122952
# [30]	training's rmse: 0.0911116	valid_1's rmse: 0.122483
# Early stopping, best iteration is:
# [25]	training's rmse: 0.0957844	valid_1's rmse: 0.122206
# Fold 7
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.113673	valid_1's rmse: 0.12292
# [20]	training's rmse: 0.101108	valid_1's rmse: 0.12082
# [30]	training's rmse: 0.0909291	valid_1's rmse: 0.120507
# Early stopping, best iteration is:
# [24]	training's rmse: 0.0967762	valid_1's rmse: 0.119978
# Fold 8
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.11229	valid_1's rmse: 0.135765
# [20]	training's rmse: 0.0994478	valid_1's rmse: 0.136096
# Early stopping, best iteration is:
# [12]	training's rmse: 0.109443	valid_1's rmse: 0.135505
# Fold 9
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.112925	valid_1's rmse: 0.128695
# [20]	training's rmse: 0.100293	valid_1's rmse: 0.126748
# [30]	training's rmse: 0.0900767	valid_1's rmse: 0.126254
# Early stopping, best iteration is:
# [26]	training's rmse: 0.0939255	valid_1's rmse: 0.126057
# Fold 10
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.114017	valid_1's rmse: 0.121192
# [20]	training's rmse: 0.101304	valid_1's rmse: 0.119717
# [30]	training's rmse: 0.0911097	valid_1's rmse: 0.119088
# Early stopping, best iteration is:
# [28]	training's rmse: 0.093045	valid_1's rmse: 0.118871
# Our oof rmse score is:  0.12531530828238194
# Train model 2
# Predicting target question_body_critical
# Fold 1
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.16353	valid_1's rmse: 0.17868
# [20]	training's rmse: 0.139944	valid_1's rmse: 0.167918
# [30]	training's rmse: 0.125364	valid_1's rmse: 0.164111
# [40]	training's rmse: 0.114146	valid_1's rmse: 0.163451
# [50]	training's rmse: 0.104575	valid_1's rmse: 0.163535
# Early stopping, best iteration is:
# [42]	training's rmse: 0.112165	valid_1's rmse: 0.163152
# Fold 2
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.163149	valid_1's rmse: 0.175724
# [20]	training's rmse: 0.139143	valid_1's rmse: 0.165573
# [30]	training's rmse: 0.124786	valid_1's rmse: 0.164305
# [40]	training's rmse: 0.113584	valid_1's rmse: 0.164041
# [50]	training's rmse: 0.104158	valid_1's rmse: 0.163251
# [60]	training's rmse: 0.0959542	valid_1's rmse: 0.16348
# Early stopping, best iteration is:
# [51]	training's rmse: 0.103275	valid_1's rmse: 0.163191
# Fold 3
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.163777	valid_1's rmse: 0.179114
# [20]	training's rmse: 0.14028	valid_1's rmse: 0.165217
# [30]	training's rmse: 0.12578	valid_1's rmse: 0.160227
# [40]	training's rmse: 0.114589	valid_1's rmse: 0.158066
# [50]	training's rmse: 0.105194	valid_1's rmse: 0.15803
# Early stopping, best iteration is:
# [43]	training's rmse: 0.111665	valid_1's rmse: 0.157742
# Fold 4
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.163674	valid_1's rmse: 0.175506
# [20]	training's rmse: 0.139602	valid_1's rmse: 0.165646
# [30]	training's rmse: 0.124978	valid_1's rmse: 0.163275
# [40]	training's rmse: 0.113927	valid_1's rmse: 0.163059
# Early stopping, best iteration is:
# [34]	training's rmse: 0.120285	valid_1's rmse: 0.162746
# Fold 5
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.163442	valid_1's rmse: 0.177275
# [20]	training's rmse: 0.139838	valid_1's rmse: 0.166209
# [30]	training's rmse: 0.125008	valid_1's rmse: 0.162888
# [40]	training's rmse: 0.113809	valid_1's rmse: 0.161267
# [50]	training's rmse: 0.104634	valid_1's rmse: 0.160265
# [60]	training's rmse: 0.0963929	valid_1's rmse: 0.160143
# [70]	training's rmse: 0.0890987	valid_1's rmse: 0.159862
# [80]	training's rmse: 0.0826731	valid_1's rmse: 0.160016
# Early stopping, best iteration is:
# [75]	training's rmse: 0.0857754	valid_1's rmse: 0.159496
# Fold 6
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.163175	valid_1's rmse: 0.181333
# [20]	training's rmse: 0.139205	valid_1's rmse: 0.170047
# [30]	training's rmse: 0.124696	valid_1's rmse: 0.166358
# [40]	training's rmse: 0.113585	valid_1's rmse: 0.164719
# [50]	training's rmse: 0.104181	valid_1's rmse: 0.165087
# Early stopping, best iteration is:
# [41]	training's rmse: 0.112603	valid_1's rmse: 0.164624
# Fold 7
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.164409	valid_1's rmse: 0.171884
# [20]	training's rmse: 0.140603	valid_1's rmse: 0.160071
# [30]	training's rmse: 0.125989	valid_1's rmse: 0.156309
# [40]	training's rmse: 0.114587	valid_1's rmse: 0.155275
# [50]	training's rmse: 0.105363	valid_1's rmse: 0.154614
# Early stopping, best iteration is:
# [49]	training's rmse: 0.106265	valid_1's rmse: 0.154575
# Fold 8
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.163895	valid_1's rmse: 0.176865
# [20]	training's rmse: 0.140298	valid_1's rmse: 0.165099
# [30]	training's rmse: 0.125653	valid_1's rmse: 0.16143
# [40]	training's rmse: 0.114274	valid_1's rmse: 0.159838
# [50]	training's rmse: 0.10459	valid_1's rmse: 0.159449
# Early stopping, best iteration is:
# [48]	training's rmse: 0.10646	valid_1's rmse: 0.159379
# Fold 9
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.16375	valid_1's rmse: 0.177689
# [20]	training's rmse: 0.139834	valid_1's rmse: 0.167034
# [30]	training's rmse: 0.125228	valid_1's rmse: 0.163947
# [40]	training's rmse: 0.113822	valid_1's rmse: 0.162231
# [50]	training's rmse: 0.104257	valid_1's rmse: 0.161771
# [60]	training's rmse: 0.0959596	valid_1's rmse: 0.162057
# Early stopping, best iteration is:
# [51]	training's rmse: 0.103345	valid_1's rmse: 0.161733
# Fold 10
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.163296	valid_1's rmse: 0.174308
# [20]	training's rmse: 0.139585	valid_1's rmse: 0.164543
# [30]	training's rmse: 0.124797	valid_1's rmse: 0.161771
# [40]	training's rmse: 0.113482	valid_1's rmse: 0.160253
# [50]	training's rmse: 0.103984	valid_1's rmse: 0.16046
# Early stopping, best iteration is:
# [40]	training's rmse: 0.113482	valid_1's rmse: 0.160253
# Our oof rmse score is:  0.1607148802441028
# Train model 3
# Predicting target question_conversational
# Fold 1
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.134952	valid_1's rmse: 0.152561
# [20]	training's rmse: 0.109988	valid_1's rmse: 0.150258
# [30]	training's rmse: 0.0948698	valid_1's rmse: 0.150044
# Early stopping, best iteration is:
# [23]	training's rmse: 0.104691	valid_1's rmse: 0.149431
# Fold 2
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.134583	valid_1's rmse: 0.168119
# [20]	training's rmse: 0.11006	valid_1's rmse: 0.165075
# [30]	training's rmse: 0.0946055	valid_1's rmse: 0.164249
# Early stopping, best iteration is:
# [24]	training's rmse: 0.103406	valid_1's rmse: 0.163673
# Fold 3
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.137268	valid_1's rmse: 0.138394
# [20]	training's rmse: 0.111713	valid_1's rmse: 0.131819
# [30]	training's rmse: 0.0964729	valid_1's rmse: 0.130166
# [40]	training's rmse: 0.0849771	valid_1's rmse: 0.129573
# [50]	training's rmse: 0.0764147	valid_1's rmse: 0.128375
# Early stopping, best iteration is:
# [49]	training's rmse: 0.0773166	valid_1's rmse: 0.12836
# Fold 4
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.134656	valid_1's rmse: 0.172224
# [20]	training's rmse: 0.110047	valid_1's rmse: 0.164753
# [30]	training's rmse: 0.0950201	valid_1's rmse: 0.164026
# [40]	training's rmse: 0.0838833	valid_1's rmse: 0.162845
# [50]	training's rmse: 0.07435	valid_1's rmse: 0.162273
# [60]	training's rmse: 0.0670416	valid_1's rmse: 0.16273
# Early stopping, best iteration is:
# [55]	training's rmse: 0.0704805	valid_1's rmse: 0.162185
# Fold 5
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.134155	valid_1's rmse: 0.173399
# [20]	training's rmse: 0.11072	valid_1's rmse: 0.166528
# [30]	training's rmse: 0.0952287	valid_1's rmse: 0.164636
# Early stopping, best iteration is:
# [24]	training's rmse: 0.103435	valid_1's rmse: 0.164212
# Fold 6
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.134589	valid_1's rmse: 0.164241
# [20]	training's rmse: 0.109522	valid_1's rmse: 0.159981
# [30]	training's rmse: 0.0943166	valid_1's rmse: 0.158413
# [40]	training's rmse: 0.0828158	valid_1's rmse: 0.158551
# Early stopping, best iteration is:
# [34]	training's rmse: 0.0893805	valid_1's rmse: 0.157839
# Fold 7
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.133783	valid_1's rmse: 0.170902
# [20]	training's rmse: 0.109201	valid_1's rmse: 0.16451
# [30]	training's rmse: 0.0930389	valid_1's rmse: 0.164542
# [40]	training's rmse: 0.0818739	valid_1's rmse: 0.163745
# Early stopping, best iteration is:
# [36]	training's rmse: 0.0859552	valid_1's rmse: 0.16349
# Fold 8
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.133996	valid_1's rmse: 0.168344
# [20]	training's rmse: 0.109571	valid_1's rmse: 0.166137
# Early stopping, best iteration is:
# [19]	training's rmse: 0.111521	valid_1's rmse: 0.165813
# Fold 9
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.134705	valid_1's rmse: 0.150966
# [20]	training's rmse: 0.109309	valid_1's rmse: 0.147439
# Early stopping, best iteration is:
# [18]	training's rmse: 0.113388	valid_1's rmse: 0.147382
# Fold 10
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.134444	valid_1's rmse: 0.154277
# [20]	training's rmse: 0.109727	valid_1's rmse: 0.152405
# [30]	training's rmse: 0.094795	valid_1's rmse: 0.151728
# Early stopping, best iteration is:
# [27]	training's rmse: 0.0986315	valid_1's rmse: 0.151406
# Our oof rmse score is:  0.1557713820905656
# Train model 4
# Predicting target question_expect_short_answer
# Fold 1
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.308764	valid_1's rmse: 0.345866
# [20]	training's rmse: 0.277723	valid_1's rmse: 0.344305
# Early stopping, best iteration is:
# [19]	training's rmse: 0.280519	valid_1's rmse: 0.344097
# Fold 2
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.309101	valid_1's rmse: 0.342698
# [20]	training's rmse: 0.278773	valid_1's rmse: 0.342106
# [30]	training's rmse: 0.254079	valid_1's rmse: 0.341901
# Early stopping, best iteration is:
# [22]	training's rmse: 0.273339	valid_1's rmse: 0.341241
# Fold 3
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.308654	valid_1's rmse: 0.348145
# [20]	training's rmse: 0.278516	valid_1's rmse: 0.345076
# [30]	training's rmse: 0.253708	valid_1's rmse: 0.347321
# Early stopping, best iteration is:
# [20]	training's rmse: 0.278516	valid_1's rmse: 0.345076
# Fold 4
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.308738	valid_1's rmse: 0.344371
# [20]	training's rmse: 0.278528	valid_1's rmse: 0.341297
# [30]	training's rmse: 0.253683	valid_1's rmse: 0.342863
# Early stopping, best iteration is:
# [23]	training's rmse: 0.270557	valid_1's rmse: 0.340969
# Fold 5
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.308428	valid_1's rmse: 0.343967
# [20]	training's rmse: 0.278262	valid_1's rmse: 0.341713
# [30]	training's rmse: 0.25289	valid_1's rmse: 0.340562
# Early stopping, best iteration is:
# [27]	training's rmse: 0.259963	valid_1's rmse: 0.340281
# Fold 6
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.309434	valid_1's rmse: 0.339656
# [20]	training's rmse: 0.279197	valid_1's rmse: 0.336295
# [30]	training's rmse: 0.254377	valid_1's rmse: 0.336125
# [40]	training's rmse: 0.23325	valid_1's rmse: 0.337376
# Early stopping, best iteration is:
# [31]	training's rmse: 0.251946	valid_1's rmse: 0.335635
# Fold 7
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.310504	valid_1's rmse: 0.32644
# [20]	training's rmse: 0.280539	valid_1's rmse: 0.325967
# Early stopping, best iteration is:
# [17]	training's rmse: 0.28891	valid_1's rmse: 0.324702
# Fold 8
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.308716	valid_1's rmse: 0.342289
# [20]	training's rmse: 0.278592	valid_1's rmse: 0.341259
# [30]	training's rmse: 0.253809	valid_1's rmse: 0.34214
# Early stopping, best iteration is:
# [24]	training's rmse: 0.268016	valid_1's rmse: 0.340886
# Fold 9
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.311002	valid_1's rmse: 0.331388
# [20]	training's rmse: 0.280718	valid_1's rmse: 0.329403
# [30]	training's rmse: 0.255673	valid_1's rmse: 0.327677
# [40]	training's rmse: 0.234337	valid_1's rmse: 0.328978
# Early stopping, best iteration is:
# [34]	training's rmse: 0.246753	valid_1's rmse: 0.327542
# Fold 10
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.308745	valid_1's rmse: 0.347914
# [20]	training's rmse: 0.278651	valid_1's rmse: 0.346817
# [30]	training's rmse: 0.253733	valid_1's rmse: 0.34753
# Early stopping, best iteration is:
# [20]	training's rmse: 0.278651	valid_1's rmse: 0.346817
# Our oof rmse score is:  0.33879475004141935
# Train model 5
# Predicting target question_fact_seeking
# Fold 1
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.254319	valid_1's rmse: 0.272831
# [20]	training's rmse: 0.22643	valid_1's rmse: 0.269334
# [30]	training's rmse: 0.204855	valid_1's rmse: 0.26994
# Early stopping, best iteration is:
# [20]	training's rmse: 0.22643	valid_1's rmse: 0.269334
# Fold 2
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.253228	valid_1's rmse: 0.278436
# [20]	training's rmse: 0.225314	valid_1's rmse: 0.270341
# [30]	training's rmse: 0.203448	valid_1's rmse: 0.268732
# [40]	training's rmse: 0.185172	valid_1's rmse: 0.269608
# Early stopping, best iteration is:
# [31]	training's rmse: 0.201364	valid_1's rmse: 0.268662
# Fold 3
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.253934	valid_1's rmse: 0.280878
# [20]	training's rmse: 0.226332	valid_1's rmse: 0.274346
# [30]	training's rmse: 0.204829	valid_1's rmse: 0.270648
# [40]	training's rmse: 0.186668	valid_1's rmse: 0.270837
# Early stopping, best iteration is:
# [31]	training's rmse: 0.202983	valid_1's rmse: 0.270151
# Fold 4
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.252996	valid_1's rmse: 0.276094
# [20]	training's rmse: 0.225	valid_1's rmse: 0.270661
# [30]	training's rmse: 0.203355	valid_1's rmse: 0.269631
# Early stopping, best iteration is:
# [23]	training's rmse: 0.218137	valid_1's rmse: 0.26919
# Fold 5
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.253379	valid_1's rmse: 0.274785
# [20]	training's rmse: 0.225655	valid_1's rmse: 0.268259
# [30]	training's rmse: 0.204511	valid_1's rmse: 0.268223
# Early stopping, best iteration is:
# [24]	training's rmse: 0.216644	valid_1's rmse: 0.267413
# Fold 6
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.253388	valid_1's rmse: 0.27474
# [20]	training's rmse: 0.225844	valid_1's rmse: 0.273368
# [30]	training's rmse: 0.204486	valid_1's rmse: 0.273152
# Early stopping, best iteration is:
# [23]	training's rmse: 0.218828	valid_1's rmse: 0.271966
# Fold 7
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.251609	valid_1's rmse: 0.290568
# [20]	training's rmse: 0.223958	valid_1's rmse: 0.286662
# [30]	training's rmse: 0.202141	valid_1's rmse: 0.286803
# Early stopping, best iteration is:
# [23]	training's rmse: 0.216706	valid_1's rmse: 0.286047
# Fold 8
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.253351	valid_1's rmse: 0.28292
# [20]	training's rmse: 0.22514	valid_1's rmse: 0.278576
# [30]	training's rmse: 0.203665	valid_1's rmse: 0.279136
# Early stopping, best iteration is:
# [26]	training's rmse: 0.211847	valid_1's rmse: 0.278113
# Fold 9
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.255294	valid_1's rmse: 0.265374
# [20]	training's rmse: 0.226784	valid_1's rmse: 0.259914
# [30]	training's rmse: 0.205293	valid_1's rmse: 0.258349
# [40]	training's rmse: 0.186979	valid_1's rmse: 0.256906
# Early stopping, best iteration is:
# [39]	training's rmse: 0.188578	valid_1's rmse: 0.256495
# Fold 10
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.253383	valid_1's rmse: 0.285902
# [20]	training's rmse: 0.225638	valid_1's rmse: 0.279763
# [30]	training's rmse: 0.203497	valid_1's rmse: 0.278681
# [40]	training's rmse: 0.185515	valid_1's rmse: 0.278734
# Early stopping, best iteration is:
# [39]	training's rmse: 0.187132	valid_1's rmse: 0.278405
# Our oof rmse score is:  0.2716803246601081
# Train model 6
# Predicting target question_has_commonly_accepted_answer
# Fold 1
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.265244	valid_1's rmse: 0.318241
# [20]	training's rmse: 0.231087	valid_1's rmse: 0.306428
# [30]	training's rmse: 0.206274	valid_1's rmse: 0.304055
# [40]	training's rmse: 0.185631	valid_1's rmse: 0.302612
# [50]	training's rmse: 0.16771	valid_1's rmse: 0.30171
# [60]	training's rmse: 0.152752	valid_1's rmse: 0.300586
# [70]	training's rmse: 0.139864	valid_1's rmse: 0.300275
# Early stopping, best iteration is:
# [67]	training's rmse: 0.143651	valid_1's rmse: 0.299961
# Fold 2
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.268514	valid_1's rmse: 0.292473
# [20]	training's rmse: 0.234536	valid_1's rmse: 0.282597
# [30]	training's rmse: 0.209785	valid_1's rmse: 0.281787
# [40]	training's rmse: 0.188882	valid_1's rmse: 0.28033
# Early stopping, best iteration is:
# [35]	training's rmse: 0.198612	valid_1's rmse: 0.279746
# Fold 3
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.268957	valid_1's rmse: 0.284932
# [20]	training's rmse: 0.234431	valid_1's rmse: 0.277584
# [30]	training's rmse: 0.209321	valid_1's rmse: 0.273982
# [40]	training's rmse: 0.188341	valid_1's rmse: 0.274642
# Early stopping, best iteration is:
# [31]	training's rmse: 0.207007	valid_1's rmse: 0.273974
# Fold 4
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.269867	valid_1's rmse: 0.284448
# [20]	training's rmse: 0.235626	valid_1's rmse: 0.273671
# [30]	training's rmse: 0.210046	valid_1's rmse: 0.268055
# [40]	training's rmse: 0.189075	valid_1's rmse: 0.26601
# [50]	training's rmse: 0.171626	valid_1's rmse: 0.265372
# [60]	training's rmse: 0.15647	valid_1's rmse: 0.263384
# Early stopping, best iteration is:
# [59]	training's rmse: 0.157735	valid_1's rmse: 0.263308
# Fold 5
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.266465	valid_1's rmse: 0.307578
# [20]	training's rmse: 0.23248	valid_1's rmse: 0.300017
# [30]	training's rmse: 0.207301	valid_1's rmse: 0.298056
# [40]	training's rmse: 0.186381	valid_1's rmse: 0.296959
# [50]	training's rmse: 0.169358	valid_1's rmse: 0.297437
# Early stopping, best iteration is:
# [41]	training's rmse: 0.184557	valid_1's rmse: 0.296591
# Fold 6
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.267703	valid_1's rmse: 0.296494
# [20]	training's rmse: 0.233102	valid_1's rmse: 0.288571
# [30]	training's rmse: 0.207548	valid_1's rmse: 0.286972
# Early stopping, best iteration is:
# [24]	training's rmse: 0.222255	valid_1's rmse: 0.286449
# Fold 7
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.266832	valid_1's rmse: 0.298597
# [20]	training's rmse: 0.232735	valid_1's rmse: 0.295503
# [30]	training's rmse: 0.207315	valid_1's rmse: 0.294054
# Early stopping, best iteration is:
# [25]	training's rmse: 0.219475	valid_1's rmse: 0.293786
# Fold 8
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.268538	valid_1's rmse: 0.289946
# [20]	training's rmse: 0.234649	valid_1's rmse: 0.281358
# [30]	training's rmse: 0.209008	valid_1's rmse: 0.282212
# Early stopping, best iteration is:
# [21]	training's rmse: 0.231974	valid_1's rmse: 0.28106
# Fold 9
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.268957	valid_1's rmse: 0.279578
# [20]	training's rmse: 0.234341	valid_1's rmse: 0.274314
# [30]	training's rmse: 0.209172	valid_1's rmse: 0.273578
# [40]	training's rmse: 0.188701	valid_1's rmse: 0.27295
# Early stopping, best iteration is:
# [33]	training's rmse: 0.202672	valid_1's rmse: 0.272445
# Fold 10
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.266981	valid_1's rmse: 0.314831
# [20]	training's rmse: 0.23327	valid_1's rmse: 0.3053
# [30]	training's rmse: 0.208004	valid_1's rmse: 0.303886
# [40]	training's rmse: 0.187118	valid_1's rmse: 0.302568
# Early stopping, best iteration is:
# [35]	training's rmse: 0.197028	valid_1's rmse: 0.302157
# Our oof rmse score is:  0.2852122316285897
# Train model 7
# Predicting target question_interestingness_others
# Fold 1
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.116423	valid_1's rmse: 0.131841
# [20]	training's rmse: 0.105305	valid_1's rmse: 0.129501
# [30]	training's rmse: 0.0963503	valid_1's rmse: 0.129799
# Early stopping, best iteration is:
# [21]	training's rmse: 0.104377	valid_1's rmse: 0.129447
# Fold 2
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.116485	valid_1's rmse: 0.131803
# [20]	training's rmse: 0.105367	valid_1's rmse: 0.130877
# [30]	training's rmse: 0.0960611	valid_1's rmse: 0.131471
# Early stopping, best iteration is:
# [22]	training's rmse: 0.10338	valid_1's rmse: 0.130718
# Fold 3
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.116768	valid_1's rmse: 0.12816
# [20]	training's rmse: 0.105558	valid_1's rmse: 0.12687
# Early stopping, best iteration is:
# [18]	training's rmse: 0.107515	valid_1's rmse: 0.126746
# Fold 4
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.117034	valid_1's rmse: 0.125872
# [20]	training's rmse: 0.105929	valid_1's rmse: 0.125743
# [30]	training's rmse: 0.0969856	valid_1's rmse: 0.125623
# Early stopping, best iteration is:
# [24]	training's rmse: 0.102187	valid_1's rmse: 0.125561
# Fold 5
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.116473	valid_1's rmse: 0.132235
# [20]	training's rmse: 0.105341	valid_1's rmse: 0.130928
# [30]	training's rmse: 0.0964369	valid_1's rmse: 0.130369
# [40]	training's rmse: 0.0887536	valid_1's rmse: 0.130486
# Early stopping, best iteration is:
# [30]	training's rmse: 0.0964369	valid_1's rmse: 0.130369
# Fold 6
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.11712	valid_1's rmse: 0.124243
# [20]	training's rmse: 0.105766	valid_1's rmse: 0.122825
# Early stopping, best iteration is:
# [17]	training's rmse: 0.108876	valid_1's rmse: 0.122771
# Fold 7
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.117293	valid_1's rmse: 0.124992
# [20]	training's rmse: 0.106051	valid_1's rmse: 0.122389
# [30]	training's rmse: 0.0970325	valid_1's rmse: 0.122405
# Early stopping, best iteration is:
# [20]	training's rmse: 0.106051	valid_1's rmse: 0.122389
# Fold 8
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.117142	valid_1's rmse: 0.124137
# [20]	training's rmse: 0.106035	valid_1's rmse: 0.123186
# [30]	training's rmse: 0.0970009	valid_1's rmse: 0.123097
# Early stopping, best iteration is:
# [27]	training's rmse: 0.0995223	valid_1's rmse: 0.122715
# Fold 9
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.11669	valid_1's rmse: 0.130097
# [20]	training's rmse: 0.10556	valid_1's rmse: 0.129068
# [30]	training's rmse: 0.0967304	valid_1's rmse: 0.128793
# Early stopping, best iteration is:
# [23]	training's rmse: 0.102744	valid_1's rmse: 0.128482
# Fold 10
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.117153	valid_1's rmse: 0.123075
# [20]	training's rmse: 0.105799	valid_1's rmse: 0.121179
# [30]	training's rmse: 0.0966458	valid_1's rmse: 0.121679
# Early stopping, best iteration is:
# [21]	training's rmse: 0.10481	valid_1's rmse: 0.121169
# Our oof rmse score is:  0.1260843140567082
# Train model 8
# Predicting target question_interestingness_self
# Fold 1
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.149997	valid_1's rmse: 0.165463
# [20]	training's rmse: 0.132219	valid_1's rmse: 0.162189
# [30]	training's rmse: 0.119254	valid_1's rmse: 0.162846
# Early stopping, best iteration is:
# [21]	training's rmse: 0.130663	valid_1's rmse: 0.162177
# Fold 2
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.150446	valid_1's rmse: 0.161341
# [20]	training's rmse: 0.132726	valid_1's rmse: 0.157222
# [30]	training's rmse: 0.119877	valid_1's rmse: 0.157559
# Early stopping, best iteration is:
# [22]	training's rmse: 0.129998	valid_1's rmse: 0.157157
# Fold 3
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.15041	valid_1's rmse: 0.162673
# [20]	training's rmse: 0.132629	valid_1's rmse: 0.160386
# [30]	training's rmse: 0.119776	valid_1's rmse: 0.159217
# [40]	training's rmse: 0.108859	valid_1's rmse: 0.159813
# Early stopping, best iteration is:
# [30]	training's rmse: 0.119776	valid_1's rmse: 0.159217
# Fold 4
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.149738	valid_1's rmse: 0.16805
# [20]	training's rmse: 0.131836	valid_1's rmse: 0.16601
# [30]	training's rmse: 0.118596	valid_1's rmse: 0.164726
# [40]	training's rmse: 0.107709	valid_1's rmse: 0.164973
# Early stopping, best iteration is:
# [37]	training's rmse: 0.110731	valid_1's rmse: 0.164575
# Fold 5
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.149024	valid_1's rmse: 0.176564
# [20]	training's rmse: 0.131906	valid_1's rmse: 0.170788
# [30]	training's rmse: 0.118998	valid_1's rmse: 0.169957
# [40]	training's rmse: 0.108228	valid_1's rmse: 0.168559
# [50]	training's rmse: 0.0989659	valid_1's rmse: 0.168436
# Early stopping, best iteration is:
# [49]	training's rmse: 0.0997827	valid_1's rmse: 0.168187
# Fold 6
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.150352	valid_1's rmse: 0.164075
# [20]	training's rmse: 0.132759	valid_1's rmse: 0.158863
# [30]	training's rmse: 0.119474	valid_1's rmse: 0.15856
# Early stopping, best iteration is:
# [27]	training's rmse: 0.123177	valid_1's rmse: 0.158121
# Fold 7
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.150734	valid_1's rmse: 0.161311
# [20]	training's rmse: 0.133134	valid_1's rmse: 0.156537
# [30]	training's rmse: 0.120045	valid_1's rmse: 0.156258
# Early stopping, best iteration is:
# [26]	training's rmse: 0.125017	valid_1's rmse: 0.156104
# Fold 8
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.150281	valid_1's rmse: 0.162747
# [20]	training's rmse: 0.132716	valid_1's rmse: 0.158977
# [30]	training's rmse: 0.119428	valid_1's rmse: 0.158497
# Early stopping, best iteration is:
# [26]	training's rmse: 0.124361	valid_1's rmse: 0.157851
# Fold 9
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.150873	valid_1's rmse: 0.159063
# [20]	training's rmse: 0.133264	valid_1's rmse: 0.156122
# [30]	training's rmse: 0.120159	valid_1's rmse: 0.15513
# Early stopping, best iteration is:
# [27]	training's rmse: 0.123809	valid_1's rmse: 0.154875
# Fold 10
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.151142	valid_1's rmse: 0.15473
# [20]	training's rmse: 0.13361	valid_1's rmse: 0.149237
# [30]	training's rmse: 0.120538	valid_1's rmse: 0.149014
# [40]	training's rmse: 0.109471	valid_1's rmse: 0.14934
# Early stopping, best iteration is:
# [32]	training's rmse: 0.118166	valid_1's rmse: 0.148731
# Our oof rmse score is:  0.1587832184582416
# Train model 9
# Predicting target question_multi_intent
# Fold 1
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.281195	valid_1's rmse: 0.320083
# [20]	training's rmse: 0.24603	valid_1's rmse: 0.309251
# [30]	training's rmse: 0.219648	valid_1's rmse: 0.304101
# [40]	training's rmse: 0.197948	valid_1's rmse: 0.303341
# [50]	training's rmse: 0.179528	valid_1's rmse: 0.303185
# [60]	training's rmse: 0.16374	valid_1's rmse: 0.302799
# [70]	training's rmse: 0.149976	valid_1's rmse: 0.301502
# [80]	training's rmse: 0.138377	valid_1's rmse: 0.301258
# Early stopping, best iteration is:
# [77]	training's rmse: 0.141835	valid_1's rmse: 0.300975
# Fold 2
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.280808	valid_1's rmse: 0.31979
# [20]	training's rmse: 0.245924	valid_1's rmse: 0.314758
# [30]	training's rmse: 0.219373	valid_1's rmse: 0.312589
# [40]	training's rmse: 0.197538	valid_1's rmse: 0.311077
# [50]	training's rmse: 0.179443	valid_1's rmse: 0.30969
# [60]	training's rmse: 0.163697	valid_1's rmse: 0.310935
# Early stopping, best iteration is:
# [51]	training's rmse: 0.177776	valid_1's rmse: 0.309542
# Fold 3
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.280713	valid_1's rmse: 0.317024
# [20]	training's rmse: 0.245872	valid_1's rmse: 0.309173
# [30]	training's rmse: 0.220244	valid_1's rmse: 0.304256
# [40]	training's rmse: 0.198337	valid_1's rmse: 0.302209
# [50]	training's rmse: 0.180533	valid_1's rmse: 0.300617
# [60]	training's rmse: 0.164644	valid_1's rmse: 0.299639
# Early stopping, best iteration is:
# [57]	training's rmse: 0.169031	valid_1's rmse: 0.299553
# Fold 4
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.281803	valid_1's rmse: 0.309079
# [20]	training's rmse: 0.246667	valid_1's rmse: 0.299565
# [30]	training's rmse: 0.22	valid_1's rmse: 0.295871
# [40]	training's rmse: 0.197937	valid_1's rmse: 0.294084
# [50]	training's rmse: 0.17949	valid_1's rmse: 0.29351
# Early stopping, best iteration is:
# [42]	training's rmse: 0.194131	valid_1's rmse: 0.2932
# Fold 5
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.282281	valid_1's rmse: 0.30606
# [20]	training's rmse: 0.247562	valid_1's rmse: 0.297157
# [30]	training's rmse: 0.221234	valid_1's rmse: 0.29323
# [40]	training's rmse: 0.199651	valid_1's rmse: 0.291285
# [50]	training's rmse: 0.181077	valid_1's rmse: 0.290364
# Early stopping, best iteration is:
# [46]	training's rmse: 0.18801	valid_1's rmse: 0.289699
# Fold 6
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.280446	valid_1's rmse: 0.319027
# [20]	training's rmse: 0.245117	valid_1's rmse: 0.309536
# [30]	training's rmse: 0.21905	valid_1's rmse: 0.308682
# [40]	training's rmse: 0.197365	valid_1's rmse: 0.306042
# [50]	training's rmse: 0.179095	valid_1's rmse: 0.305978
# Early stopping, best iteration is:
# [45]	training's rmse: 0.187812	valid_1's rmse: 0.305625
# Fold 7
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.281319	valid_1's rmse: 0.309082
# [20]	training's rmse: 0.246266	valid_1's rmse: 0.301692
# [30]	training's rmse: 0.220441	valid_1's rmse: 0.301078
# [40]	training's rmse: 0.198823	valid_1's rmse: 0.299168
# [50]	training's rmse: 0.180831	valid_1's rmse: 0.298423
# Early stopping, best iteration is:
# [49]	training's rmse: 0.182346	valid_1's rmse: 0.298215
# Fold 8
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.283685	valid_1's rmse: 0.289279
# [20]	training's rmse: 0.248951	valid_1's rmse: 0.279497
# [30]	training's rmse: 0.222461	valid_1's rmse: 0.274981
# [40]	training's rmse: 0.200933	valid_1's rmse: 0.271381
# [50]	training's rmse: 0.182617	valid_1's rmse: 0.269573
# [60]	training's rmse: 0.166625	valid_1's rmse: 0.267693
# Early stopping, best iteration is:
# [59]	training's rmse: 0.168057	valid_1's rmse: 0.267627
# Fold 9
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.280264	valid_1's rmse: 0.321538
# [20]	training's rmse: 0.246059	valid_1's rmse: 0.310855
# [30]	training's rmse: 0.219653	valid_1's rmse: 0.306532
# [40]	training's rmse: 0.198021	valid_1's rmse: 0.304059
# Early stopping, best iteration is:
# [37]	training's rmse: 0.204029	valid_1's rmse: 0.303587
# Fold 10
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.28172	valid_1's rmse: 0.316204
# [20]	training's rmse: 0.24763	valid_1's rmse: 0.305272
# [30]	training's rmse: 0.221173	valid_1's rmse: 0.298028
# [40]	training's rmse: 0.198827	valid_1's rmse: 0.295362
# [50]	training's rmse: 0.180552	valid_1's rmse: 0.293867
# [60]	training's rmse: 0.165386	valid_1's rmse: 0.292183
# [70]	training's rmse: 0.151617	valid_1's rmse: 0.29143
# Early stopping, best iteration is:
# [69]	training's rmse: 0.152965	valid_1's rmse: 0.291022
# Our oof rmse score is:  0.29611701564418563
# Train model 10
# Predicting target question_not_really_a_question
# Fold 1
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.0416584	valid_1's rmse: 0.0343107
# Early stopping, best iteration is:
# [2]	training's rmse: 0.0457691	valid_1's rmse: 0.0335614
# Fold 2
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.0418007	valid_1's rmse: 0.0278002
# Early stopping, best iteration is:
# [1]	training's rmse: 0.0467465	valid_1's rmse: 0.0271734
# Fold 3
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.0415547	valid_1's rmse: 0.0361597
# Early stopping, best iteration is:
# [2]	training's rmse: 0.0456161	valid_1's rmse: 0.0360593
# Fold 4
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.0357927	valid_1's rmse: 0.0789026
# Early stopping, best iteration is:
# [1]	training's rmse: 0.0399957	valid_1's rmse: 0.0787062
# Fold 5
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.0412643	valid_1's rmse: 0.0372168
# Early stopping, best iteration is:
# [1]	training's rmse: 0.0460738	valid_1's rmse: 0.0362931
# Fold 6
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.0408356	valid_1's rmse: 0.0416783
# Early stopping, best iteration is:
# [1]	training's rmse: 0.0456175	valid_1's rmse: 0.0410406
# Fold 7
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.0401368	valid_1's rmse: 0.045489
# Early stopping, best iteration is:
# [5]	training's rmse: 0.042724	valid_1's rmse: 0.0454056
# Fold 8
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.0386291	valid_1's rmse: 0.0636245
# Early stopping, best iteration is:
# [1]	training's rmse: 0.0428284	valid_1's rmse: 0.0633829
# Fold 9
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.0416862	valid_1's rmse: 0.028041
# Early stopping, best iteration is:
# [4]	training's rmse: 0.0451358	valid_1's rmse: 0.0279558
# Fold 10
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.040901	valid_1's rmse: 0.041619
# Early stopping, best iteration is:
# [1]	training's rmse: 0.0456678	valid_1's rmse: 0.0414866
# Our oof rmse score is:  0.04576412954245512
# Train model 11
# Predicting target question_opinion_seeking
# Fold 1
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.307046	valid_1's rmse: 0.339767
# [20]	training's rmse: 0.273357	valid_1's rmse: 0.328601
# [30]	training's rmse: 0.24781	valid_1's rmse: 0.324614
# [40]	training's rmse: 0.226539	valid_1's rmse: 0.324425
# Early stopping, best iteration is:
# [39]	training's rmse: 0.228476	valid_1's rmse: 0.324403
# Fold 2
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.306247	valid_1's rmse: 0.34424
# [20]	training's rmse: 0.272283	valid_1's rmse: 0.337411
# [30]	training's rmse: 0.246961	valid_1's rmse: 0.336228
# Early stopping, best iteration is:
# [24]	training's rmse: 0.261484	valid_1's rmse: 0.33585
# Fold 3
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.307222	valid_1's rmse: 0.328388
# [20]	training's rmse: 0.273765	valid_1's rmse: 0.319955
# [30]	training's rmse: 0.248137	valid_1's rmse: 0.31838
# [40]	training's rmse: 0.227524	valid_1's rmse: 0.31646
# [50]	training's rmse: 0.209806	valid_1's rmse: 0.317558
# Early stopping, best iteration is:
# [40]	training's rmse: 0.227524	valid_1's rmse: 0.31646
# Fold 4
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.306661	valid_1's rmse: 0.329804
# [20]	training's rmse: 0.273183	valid_1's rmse: 0.323983
# [30]	training's rmse: 0.247979	valid_1's rmse: 0.322731
# Early stopping, best iteration is:
# [24]	training's rmse: 0.262583	valid_1's rmse: 0.322214
# Fold 5
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.307325	valid_1's rmse: 0.33697
# [20]	training's rmse: 0.274175	valid_1's rmse: 0.327985
# [30]	training's rmse: 0.248626	valid_1's rmse: 0.326237
# [40]	training's rmse: 0.227833	valid_1's rmse: 0.324115
# [50]	training's rmse: 0.209541	valid_1's rmse: 0.323664
# Early stopping, best iteration is:
# [45]	training's rmse: 0.21821	valid_1's rmse: 0.323049
# Fold 6
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.307517	valid_1's rmse: 0.33713
# [20]	training's rmse: 0.273919	valid_1's rmse: 0.328189
# [30]	training's rmse: 0.248212	valid_1's rmse: 0.327315
# [40]	training's rmse: 0.226592	valid_1's rmse: 0.325756
# [50]	training's rmse: 0.208644	valid_1's rmse: 0.326725
# Early stopping, best iteration is:
# [42]	training's rmse: 0.222806	valid_1's rmse: 0.32525
# Fold 7
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.307597	valid_1's rmse: 0.33222
# [20]	training's rmse: 0.274442	valid_1's rmse: 0.325501
# [30]	training's rmse: 0.248869	valid_1's rmse: 0.322502
# [40]	training's rmse: 0.227808	valid_1's rmse: 0.32192
# [50]	training's rmse: 0.209684	valid_1's rmse: 0.320011
# [60]	training's rmse: 0.1943	valid_1's rmse: 0.321401
# Early stopping, best iteration is:
# [51]	training's rmse: 0.208158	valid_1's rmse: 0.319735
# Fold 8
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.307914	valid_1's rmse: 0.328726
# [20]	training's rmse: 0.274365	valid_1's rmse: 0.319516
# [30]	training's rmse: 0.249153	valid_1's rmse: 0.315883
# Early stopping, best iteration is:
# [29]	training's rmse: 0.251511	valid_1's rmse: 0.315753
# Fold 9
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.307317	valid_1's rmse: 0.334618
# [20]	training's rmse: 0.273971	valid_1's rmse: 0.326413
# [30]	training's rmse: 0.248527	valid_1's rmse: 0.324301
# [40]	training's rmse: 0.227281	valid_1's rmse: 0.323423
# [50]	training's rmse: 0.208722	valid_1's rmse: 0.322912
# [60]	training's rmse: 0.192655	valid_1's rmse: 0.321714
# [70]	training's rmse: 0.178614	valid_1's rmse: 0.323379
# Early stopping, best iteration is:
# [60]	training's rmse: 0.192655	valid_1's rmse: 0.321714
# Fold 10
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.307317	valid_1's rmse: 0.333954
# [20]	training's rmse: 0.274287	valid_1's rmse: 0.327734
# [30]	training's rmse: 0.248465	valid_1's rmse: 0.325939
# [40]	training's rmse: 0.226718	valid_1's rmse: 0.324996
# [50]	training's rmse: 0.208842	valid_1's rmse: 0.324985
# Early stopping, best iteration is:
# [46]	training's rmse: 0.2156	valid_1's rmse: 0.324229
# Our oof rmse score is:  0.322909014793409
# Train model 12
# Predicting target question_type_choice
# Fold 1
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.264298	valid_1's rmse: 0.27514
# [20]	training's rmse: 0.223651	valid_1's rmse: 0.252566
# [30]	training's rmse: 0.198283	valid_1's rmse: 0.248287
# [40]	training's rmse: 0.17878	valid_1's rmse: 0.247766
# [50]	training's rmse: 0.162313	valid_1's rmse: 0.247262
# [60]	training's rmse: 0.148366	valid_1's rmse: 0.246616
# [70]	training's rmse: 0.136537	valid_1's rmse: 0.245517
# [80]	training's rmse: 0.125959	valid_1's rmse: 0.245566
# Early stopping, best iteration is:
# [72]	training's rmse: 0.134337	valid_1's rmse: 0.245294
# Fold 2
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.259992	valid_1's rmse: 0.292048
# [20]	training's rmse: 0.219085	valid_1's rmse: 0.280543
# [30]	training's rmse: 0.193804	valid_1's rmse: 0.277206
# [40]	training's rmse: 0.174699	valid_1's rmse: 0.276234
# [50]	training's rmse: 0.158672	valid_1's rmse: 0.276365
# [60]	training's rmse: 0.145389	valid_1's rmse: 0.276043
# Early stopping, best iteration is:
# [57]	training's rmse: 0.149155	valid_1's rmse: 0.275749
# Fold 3
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.261753	valid_1's rmse: 0.289885
# [20]	training's rmse: 0.220775	valid_1's rmse: 0.272635
# [30]	training's rmse: 0.196069	valid_1's rmse: 0.268632
# [40]	training's rmse: 0.176663	valid_1's rmse: 0.266432
# [50]	training's rmse: 0.160381	valid_1's rmse: 0.265932
# [60]	training's rmse: 0.146803	valid_1's rmse: 0.265411
# Early stopping, best iteration is:
# [58]	training's rmse: 0.149191	valid_1's rmse: 0.265157
# Fold 4
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.262646	valid_1's rmse: 0.282935
# [20]	training's rmse: 0.222885	valid_1's rmse: 0.266404
# [30]	training's rmse: 0.197778	valid_1's rmse: 0.262512
# [40]	training's rmse: 0.178228	valid_1's rmse: 0.260108
# [50]	training's rmse: 0.162443	valid_1's rmse: 0.259212
# Early stopping, best iteration is:
# [44]	training's rmse: 0.171626	valid_1's rmse: 0.258626
# Fold 5
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.262476	valid_1's rmse: 0.285619
# [20]	training's rmse: 0.221412	valid_1's rmse: 0.267668
# [30]	training's rmse: 0.196289	valid_1's rmse: 0.264728
# Early stopping, best iteration is:
# [27]	training's rmse: 0.20305	valid_1's rmse: 0.264567
# Fold 6
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.261556	valid_1's rmse: 0.287785
# [20]	training's rmse: 0.220635	valid_1's rmse: 0.270882
# [30]	training's rmse: 0.195306	valid_1's rmse: 0.266271
# [40]	training's rmse: 0.176322	valid_1's rmse: 0.26381
# [50]	training's rmse: 0.159991	valid_1's rmse: 0.263135
# [60]	training's rmse: 0.146128	valid_1's rmse: 0.262586
# [70]	training's rmse: 0.134366	valid_1's rmse: 0.262121
# [80]	training's rmse: 0.123544	valid_1's rmse: 0.261623
# [90]	training's rmse: 0.11399	valid_1's rmse: 0.261328
# [100]	training's rmse: 0.105383	valid_1's rmse: 0.261537
# Early stopping, best iteration is:
# [92]	training's rmse: 0.112129	valid_1's rmse: 0.26123
# Fold 7
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.262924	valid_1's rmse: 0.287056
# [20]	training's rmse: 0.222042	valid_1's rmse: 0.270026
# [30]	training's rmse: 0.196499	valid_1's rmse: 0.266186
# [40]	training's rmse: 0.176584	valid_1's rmse: 0.265827
# [50]	training's rmse: 0.160446	valid_1's rmse: 0.265446
# Early stopping, best iteration is:
# [47]	training's rmse: 0.164977	valid_1's rmse: 0.265052
# Fold 8
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.262509	valid_1's rmse: 0.296692
# [20]	training's rmse: 0.222447	valid_1's rmse: 0.279212
# [30]	training's rmse: 0.197871	valid_1's rmse: 0.273218
# [40]	training's rmse: 0.178444	valid_1's rmse: 0.272228
# [50]	training's rmse: 0.162162	valid_1's rmse: 0.270307
# [60]	training's rmse: 0.148214	valid_1's rmse: 0.269167
# [70]	training's rmse: 0.135878	valid_1's rmse: 0.267577
# [80]	training's rmse: 0.125143	valid_1's rmse: 0.266292
# [90]	training's rmse: 0.115889	valid_1's rmse: 0.265925
# [100]	training's rmse: 0.107207	valid_1's rmse: 0.264777
# [110]	training's rmse: 0.0996702	valid_1's rmse: 0.263919
# [120]	training's rmse: 0.092575	valid_1's rmse: 0.264144
# Early stopping, best iteration is:
# [110]	training's rmse: 0.0996702	valid_1's rmse: 0.263919
# Fold 9
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.261847	valid_1's rmse: 0.291306
# [20]	training's rmse: 0.220609	valid_1's rmse: 0.276908
# [30]	training's rmse: 0.196035	valid_1's rmse: 0.272661
# [40]	training's rmse: 0.176474	valid_1's rmse: 0.27086
# [50]	training's rmse: 0.160119	valid_1's rmse: 0.271295
# Early stopping, best iteration is:
# [42]	training's rmse: 0.172845	valid_1's rmse: 0.270552
# Fold 10
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.262281	valid_1's rmse: 0.293381
# [20]	training's rmse: 0.2217	valid_1's rmse: 0.274667
# [30]	training's rmse: 0.196461	valid_1's rmse: 0.26842
# [40]	training's rmse: 0.176846	valid_1's rmse: 0.266862
# [50]	training's rmse: 0.160543	valid_1's rmse: 0.267597
# Early stopping, best iteration is:
# [41]	training's rmse: 0.175098	valid_1's rmse: 0.266632
# Our oof rmse score is:  0.26378660839103235
# Train model 13
# Predicting target question_type_compare
# Fold 1
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.105166	valid_1's rmse: 0.125503
# [20]	training's rmse: 0.0835077	valid_1's rmse: 0.122736
# Early stopping, best iteration is:
# [16]	training's rmse: 0.0904572	valid_1's rmse: 0.122269
# Fold 2
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.106427	valid_1's rmse: 0.101993
# [20]	training's rmse: 0.0852256	valid_1's rmse: 0.0983052
# [30]	training's rmse: 0.0738171	valid_1's rmse: 0.0985457
# Early stopping, best iteration is:
# [23]	training's rmse: 0.0814008	valid_1's rmse: 0.0981113
# Fold 3
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.103141	valid_1's rmse: 0.139668
# [20]	training's rmse: 0.0826502	valid_1's rmse: 0.13412
# [30]	training's rmse: 0.0709762	valid_1's rmse: 0.133291
# [40]	training's rmse: 0.0623073	valid_1's rmse: 0.132638
# [50]	training's rmse: 0.055377	valid_1's rmse: 0.13251
# [60]	training's rmse: 0.049709	valid_1's rmse: 0.132623
# ...
# [40]	training's rmse: 0.1932	valid_1's rmse: 0.287883
# [50]	training's rmse: 0.175293	valid_1's rmse: 0.287481
# [60]	training's rmse: 0.160313	valid_1's rmse: 0.285846
# [70]	training's rmse: 0.147177	valid_1's rmse: 0.285178
# [80]	training's rmse: 0.135498	valid_1's rmse: 0.286189
# Early stopping, best iteration is:
# [70]	training's rmse: 0.147177	valid_1's rmse: 0.285178
# Fold 4
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.294641	valid_1's rmse: 0.318848
# [20]	training's rmse: 0.243266	valid_1's rmse: 0.290035
# [30]	training's rmse: 0.213538	valid_1's rmse: 0.282736
# [40]	training's rmse: 0.191705	valid_1's rmse: 0.279601
# [50]	training's rmse: 0.174034	valid_1's rmse: 0.278857
# Early stopping, best iteration is:
# [48]	training's rmse: 0.177393	valid_1's rmse: 0.278675
# Fold 5
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.29502	valid_1's rmse: 0.312295
# [20]	training's rmse: 0.243922	valid_1's rmse: 0.282007
# [30]	training's rmse: 0.214793	valid_1's rmse: 0.275591
# [40]	training's rmse: 0.193514	valid_1's rmse: 0.271291
# [50]	training's rmse: 0.175829	valid_1's rmse: 0.26937
# [60]	training's rmse: 0.160893	valid_1's rmse: 0.269854
# Early stopping, best iteration is:
# [53]	training's rmse: 0.171264	valid_1's rmse: 0.268856
# Fold 6
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.294432	valid_1's rmse: 0.314808
# [20]	training's rmse: 0.244407	valid_1's rmse: 0.289081
# [30]	training's rmse: 0.215393	valid_1's rmse: 0.281494
# [40]	training's rmse: 0.193865	valid_1's rmse: 0.276785
# [50]	training's rmse: 0.176145	valid_1's rmse: 0.275733
# [60]	training's rmse: 0.160878	valid_1's rmse: 0.275041
# [70]	training's rmse: 0.147885	valid_1's rmse: 0.274638
# [80]	training's rmse: 0.136224	valid_1's rmse: 0.274484
# Early stopping, best iteration is:
# [75]	training's rmse: 0.141802	valid_1's rmse: 0.274211
# Fold 7
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.295035	valid_1's rmse: 0.319766
# [20]	training's rmse: 0.244769	valid_1's rmse: 0.289351
# [30]	training's rmse: 0.215341	valid_1's rmse: 0.277794
# [40]	training's rmse: 0.193539	valid_1's rmse: 0.273462
# [50]	training's rmse: 0.175926	valid_1's rmse: 0.271336
# [60]	training's rmse: 0.160914	valid_1's rmse: 0.269438
# [70]	training's rmse: 0.148155	valid_1's rmse: 0.269227
# [80]	training's rmse: 0.136964	valid_1's rmse: 0.268999
# Early stopping, best iteration is:
# [72]	training's rmse: 0.145686	valid_1's rmse: 0.268506
# Fold 8
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.293447	valid_1's rmse: 0.320144
# [20]	training's rmse: 0.242657	valid_1's rmse: 0.299242
# [30]	training's rmse: 0.213423	valid_1's rmse: 0.292397
# [40]	training's rmse: 0.192133	valid_1's rmse: 0.288392
# [50]	training's rmse: 0.1742	valid_1's rmse: 0.287623
# [60]	training's rmse: 0.158993	valid_1's rmse: 0.287781
# Early stopping, best iteration is:
# [53]	training's rmse: 0.169419	valid_1's rmse: 0.286855
# Fold 9
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.291431	valid_1's rmse: 0.337327
# [20]	training's rmse: 0.241185	valid_1's rmse: 0.314759
# [30]	training's rmse: 0.212612	valid_1's rmse: 0.309548
# [40]	training's rmse: 0.191496	valid_1's rmse: 0.30701
# [50]	training's rmse: 0.173905	valid_1's rmse: 0.304887
# [60]	training's rmse: 0.158645	valid_1's rmse: 0.303128
# [70]	training's rmse: 0.145958	valid_1's rmse: 0.302566
# Early stopping, best iteration is:
# [69]	training's rmse: 0.147146	valid_1's rmse: 0.30253
# Fold 10
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.293679	valid_1's rmse: 0.32809
# [20]	training's rmse: 0.242169	valid_1's rmse: 0.305521
# [30]	training's rmse: 0.213263	valid_1's rmse: 0.298058
# [40]	training's rmse: 0.192011	valid_1's rmse: 0.295022
# [50]	training's rmse: 0.174605	valid_1's rmse: 0.293985
# [60]	training's rmse: 0.159756	valid_1's rmse: 0.293085
# [70]	training's rmse: 0.146614	valid_1's rmse: 0.2924
# Early stopping, best iteration is:
# [65]	training's rmse: 0.15279	valid_1's rmse: 0.292208
# Our oof rmse score is:  0.2835038812916996
# Train model 28
# Predicting target answer_type_procedure
# Fold 1
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.196047	valid_1's rmse: 0.226128
# [20]	training's rmse: 0.174151	valid_1's rmse: 0.226465
# [30]	training's rmse: 0.156209	valid_1's rmse: 0.225572
# [40]	training's rmse: 0.141144	valid_1's rmse: 0.224653
# [50]	training's rmse: 0.128294	valid_1's rmse: 0.225112
# Early stopping, best iteration is:
# [43]	training's rmse: 0.136994	valid_1's rmse: 0.224279
# Fold 2
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.196236	valid_1's rmse: 0.227113
# [20]	training's rmse: 0.173994	valid_1's rmse: 0.226089
# [30]	training's rmse: 0.155842	valid_1's rmse: 0.225009
# [40]	training's rmse: 0.140775	valid_1's rmse: 0.22445
# Early stopping, best iteration is:
# [38]	training's rmse: 0.143507	valid_1's rmse: 0.224346
# Fold 3
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.197361	valid_1's rmse: 0.216119
# [20]	training's rmse: 0.175344	valid_1's rmse: 0.215844
# Early stopping, best iteration is:
# [13]	training's rmse: 0.190329	valid_1's rmse: 0.215833
# Fold 4
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.195375	valid_1's rmse: 0.233188
# [20]	training's rmse: 0.173175	valid_1's rmse: 0.231921
# Early stopping, best iteration is:
# [17]	training's rmse: 0.179256	valid_1's rmse: 0.231407
# Fold 5
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.195381	valid_1's rmse: 0.231579
# [20]	training's rmse: 0.173202	valid_1's rmse: 0.231565
# Early stopping, best iteration is:
# [12]	training's rmse: 0.190429	valid_1's rmse: 0.230893
# Fold 6
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.197203	valid_1's rmse: 0.21604
# [20]	training's rmse: 0.175438	valid_1's rmse: 0.216396
# Early stopping, best iteration is:
# [12]	training's rmse: 0.192255	valid_1's rmse: 0.215505
# Fold 7
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.197929	valid_1's rmse: 0.21128
# [20]	training's rmse: 0.175546	valid_1's rmse: 0.212451
# Early stopping, best iteration is:
# [11]	training's rmse: 0.19557	valid_1's rmse: 0.211152
# Fold 8
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.196273	valid_1's rmse: 0.229063
# [20]	training's rmse: 0.174209	valid_1's rmse: 0.227642
# [30]	training's rmse: 0.156141	valid_1's rmse: 0.227894
# [40]	training's rmse: 0.140802	valid_1's rmse: 0.227965
# Early stopping, best iteration is:
# [36]	training's rmse: 0.146617	valid_1's rmse: 0.227459
# Fold 9
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.196736	valid_1's rmse: 0.22397
# [20]	training's rmse: 0.174764	valid_1's rmse: 0.225063
# Early stopping, best iteration is:
# [14]	training's rmse: 0.187571	valid_1's rmse: 0.223788
# Fold 10
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.198596	valid_1's rmse: 0.204627
# [20]	training's rmse: 0.176051	valid_1's rmse: 0.204118
# [30]	training's rmse: 0.157445	valid_1's rmse: 0.203183
# [40]	training's rmse: 0.142367	valid_1's rmse: 0.204287
# Early stopping, best iteration is:
# [31]	training's rmse: 0.155868	valid_1's rmse: 0.202873
# Our oof rmse score is:  0.22092836202903732
# Train model 29
# Predicting target answer_type_reason_explanation
# Fold 1
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.313581	valid_1's rmse: 0.343237
# [20]	training's rmse: 0.267563	valid_1's rmse: 0.32523
# [30]	training's rmse: 0.237532	valid_1's rmse: 0.321135
# [40]	training's rmse: 0.214269	valid_1's rmse: 0.317972
# [50]	training's rmse: 0.195249	valid_1's rmse: 0.317807
# [60]	training's rmse: 0.178539	valid_1's rmse: 0.317362
# [70]	training's rmse: 0.164276	valid_1's rmse: 0.317661
# Early stopping, best iteration is:
# [65]	training's rmse: 0.171076	valid_1's rmse: 0.316731
# Fold 2
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.313984	valid_1's rmse: 0.348632
# [20]	training's rmse: 0.269036	valid_1's rmse: 0.329728
# [30]	training's rmse: 0.239141	valid_1's rmse: 0.32179
# [40]	training's rmse: 0.215679	valid_1's rmse: 0.318064
# [50]	training's rmse: 0.196514	valid_1's rmse: 0.317482
# [60]	training's rmse: 0.179834	valid_1's rmse: 0.317817
# Early stopping, best iteration is:
# [56]	training's rmse: 0.186387	valid_1's rmse: 0.316965
# Fold 3
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.31505	valid_1's rmse: 0.338699
# [20]	training's rmse: 0.270111	valid_1's rmse: 0.319089
# [30]	training's rmse: 0.2403	valid_1's rmse: 0.310804
# [40]	training's rmse: 0.217276	valid_1's rmse: 0.307679
# [50]	training's rmse: 0.197905	valid_1's rmse: 0.307029
# [60]	training's rmse: 0.181519	valid_1's rmse: 0.307365
# [70]	training's rmse: 0.167222	valid_1's rmse: 0.306346
# [80]	training's rmse: 0.154497	valid_1's rmse: 0.30495
# [90]	training's rmse: 0.143012	valid_1's rmse: 0.304786
# Early stopping, best iteration is:
# [89]	training's rmse: 0.144111	valid_1's rmse: 0.304526
# Fold 4
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.314184	valid_1's rmse: 0.345548
# [20]	training's rmse: 0.269637	valid_1's rmse: 0.323835
# [30]	training's rmse: 0.239572	valid_1's rmse: 0.315108
# [40]	training's rmse: 0.21646	valid_1's rmse: 0.3107
# [50]	training's rmse: 0.196795	valid_1's rmse: 0.30831
# [60]	training's rmse: 0.179912	valid_1's rmse: 0.308408
# Early stopping, best iteration is:
# [54]	training's rmse: 0.18978	valid_1's rmse: 0.307921
# Fold 5
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.314748	valid_1's rmse: 0.34408
# [20]	training's rmse: 0.26981	valid_1's rmse: 0.327688
# [30]	training's rmse: 0.240019	valid_1's rmse: 0.319932
# [40]	training's rmse: 0.216731	valid_1's rmse: 0.318504
# [50]	training's rmse: 0.19744	valid_1's rmse: 0.315393
# [60]	training's rmse: 0.180913	valid_1's rmse: 0.313784
# [70]	training's rmse: 0.166252	valid_1's rmse: 0.313942
# Early stopping, best iteration is:
# [65]	training's rmse: 0.173374	valid_1's rmse: 0.313315
# Fold 6
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.31543	valid_1's rmse: 0.33373
# [20]	training's rmse: 0.270169	valid_1's rmse: 0.314073
# [30]	training's rmse: 0.239887	valid_1's rmse: 0.309842
# [40]	training's rmse: 0.216529	valid_1's rmse: 0.306193
# [50]	training's rmse: 0.19719	valid_1's rmse: 0.30573
# [60]	training's rmse: 0.180367	valid_1's rmse: 0.305222
# Early stopping, best iteration is:
# [54]	training's rmse: 0.190107	valid_1's rmse: 0.30492
# Fold 7
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.314967	valid_1's rmse: 0.344075
# [20]	training's rmse: 0.270109	valid_1's rmse: 0.325027
# [30]	training's rmse: 0.239906	valid_1's rmse: 0.316049
# [40]	training's rmse: 0.216801	valid_1's rmse: 0.313064
# [50]	training's rmse: 0.197444	valid_1's rmse: 0.310487
# [60]	training's rmse: 0.180575	valid_1's rmse: 0.309493
# [70]	training's rmse: 0.16591	valid_1's rmse: 0.309056
# [80]	training's rmse: 0.153612	valid_1's rmse: 0.308766
# [90]	training's rmse: 0.142656	valid_1's rmse: 0.308955
# Early stopping, best iteration is:
# [82]	training's rmse: 0.151328	valid_1's rmse: 0.308551
# Fold 8
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.316259	valid_1's rmse: 0.326997
# [20]	training's rmse: 0.271481	valid_1's rmse: 0.305629
# [30]	training's rmse: 0.241386	valid_1's rmse: 0.297666
# [40]	training's rmse: 0.217955	valid_1's rmse: 0.293864
# [50]	training's rmse: 0.198327	valid_1's rmse: 0.291513
# [60]	training's rmse: 0.181266	valid_1's rmse: 0.291338
# [70]	training's rmse: 0.166508	valid_1's rmse: 0.292037
# Early stopping, best iteration is:
# [61]	training's rmse: 0.179703	valid_1's rmse: 0.29123
# Fold 9
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.312637	valid_1's rmse: 0.35339
# [20]	training's rmse: 0.267527	valid_1's rmse: 0.336717
# [30]	training's rmse: 0.23778	valid_1's rmse: 0.330965
# [40]	training's rmse: 0.214881	valid_1's rmse: 0.327436
# [50]	training's rmse: 0.195465	valid_1's rmse: 0.326355
# [60]	training's rmse: 0.179013	valid_1's rmse: 0.325822
# [70]	training's rmse: 0.164559	valid_1's rmse: 0.325847
# [80]	training's rmse: 0.152059	valid_1's rmse: 0.325058
# [90]	training's rmse: 0.141057	valid_1's rmse: 0.32523
# Early stopping, best iteration is:
# [81]	training's rmse: 0.150903	valid_1's rmse: 0.324792
# Fold 10
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.314597	valid_1's rmse: 0.345146
# [20]	training's rmse: 0.269502	valid_1's rmse: 0.328787
# [30]	training's rmse: 0.239567	valid_1's rmse: 0.323793
# [40]	training's rmse: 0.216415	valid_1's rmse: 0.320119
# [50]	training's rmse: 0.197145	valid_1's rmse: 0.319101
# [60]	training's rmse: 0.180383	valid_1's rmse: 0.319667
# Early stopping, best iteration is:
# [50]	training's rmse: 0.197145	valid_1's rmse: 0.319101
# Our oof rmse score is:  0.3109347504192032
# Train model 30
# Predicting target answer_well_written
# Fold 1
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.0902027	valid_1's rmse: 0.096456
# [20]	training's rmse: 0.0816602	valid_1's rmse: 0.0961945
# [30]	training's rmse: 0.0743291	valid_1's rmse: 0.0968816
# Early stopping, best iteration is:
# [20]	training's rmse: 0.0816602	valid_1's rmse: 0.0961945
# Fold 2
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.0894889	valid_1's rmse: 0.101486
# [20]	training's rmse: 0.0808806	valid_1's rmse: 0.10136
# Early stopping, best iteration is:
# [18]	training's rmse: 0.0824304	valid_1's rmse: 0.101175
# Fold 3
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.0896332	valid_1's rmse: 0.098379
# Early stopping, best iteration is:
# [4]	training's rmse: 0.0960089	valid_1's rmse: 0.0979715
# Fold 4
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.0892687	valid_1's rmse: 0.105822
# [20]	training's rmse: 0.0806986	valid_1's rmse: 0.105453
# [30]	training's rmse: 0.0735876	valid_1's rmse: 0.105565
# Early stopping, best iteration is:
# [23]	training's rmse: 0.0784185	valid_1's rmse: 0.105274
# Fold 5
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.0896663	valid_1's rmse: 0.0990752
# Early stopping, best iteration is:
# [4]	training's rmse: 0.0959532	valid_1's rmse: 0.0987057
# Fold 6
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.0897123	valid_1's rmse: 0.101915
# Early stopping, best iteration is:
# [3]	training's rmse: 0.096997	valid_1's rmse: 0.10124
# Fold 7
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.0893928	valid_1's rmse: 0.101296
# [20]	training's rmse: 0.0807689	valid_1's rmse: 0.101307
# [30]	training's rmse: 0.0736685	valid_1's rmse: 0.10153
# Early stopping, best iteration is:
# [24]	training's rmse: 0.0777723	valid_1's rmse: 0.101066
# Fold 8
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.0896561	valid_1's rmse: 0.100093
# [20]	training's rmse: 0.0810355	valid_1's rmse: 0.100441
# Early stopping, best iteration is:
# [10]	training's rmse: 0.0896561	valid_1's rmse: 0.100093
# Fold 9
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.0898684	valid_1's rmse: 0.0985577
# Early stopping, best iteration is:
# [3]	training's rmse: 0.0973427	valid_1's rmse: 0.0976704
# Fold 10
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 0.0900747	valid_1's rmse: 0.0982081
# [20]	training's rmse: 0.0815179	valid_1's rmse: 0.0978203
# Early stopping, best iteration is:
# [16]	training's rmse: 0.0847448	valid_1's rmse: 0.0976972
# Our oof rmse score is:  0.09974023061942221
